# %% [markdown]
# # 0. Make DataSet

# %%
# 1. 서포트 벡터 머신 회귀(sklearn.svm.SVR)를 kernel="linear"나 kernel="rbf"등의 다양한 하이퍼파라미터 설정으로 시도해보세요. 최상의 SVR 모델은 ?
# 데이터셋 => num 데이터는 num끼리 text 데이터는 one hot (ocean_proximity)->corr가 낮은 데이터는 제거
# 추가 특성 조합
# rooms_per_houshold = rooms/household
# population_per_household = population/household
# bedrooms_per_room = bedrooms/rooms

"""
1. 데이터셋 다운로드 및 테스트 분리
2. 데이터셋 조합기 생성
3. 데이터셋 파이프라인 생성
4. num, cat 파이프라인 merge 생성
5. gridSearch 조합
6. 학습 및 비교
7. 그래프
"""

import urllib.request
import os
import tarfile

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/rickiepark/handson-ml2/master/"
HOUSING_PATH=os.path.join('datasets','housing')
HOUSING_URL = DOWNLOAD_ROOT + 'datasets/housing/housing.tgz'

def fetch_housing_data(housing_url, housing_path):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
        
    tgz_path = os.path.join(housing_path, 'housing.tgz')
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
fetch_housing_data(HOUSING_URL, HOUSING_PATH)

# %%
import pandas as pd

def load_housing_data(housing_path):
    csv_path = os.path.join(housing_path, 'housing.csv')
    return pd.read_csv(csv_path)

# %%
import numpy as np

housing = load_housing_data(HOUSING_PATH)

np.random.seed(42)

housing["income_cat"] = pd.cut(housing["median_income"],
                               bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
                               labels=[1, 2, 3, 4, 5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
housing = strat_train_set.drop("median_house_value", axis=1) # 훈련 세트를 위해 레이블 삭제
housing_labels = strat_train_set["median_house_value"].copy()
housing.count() # bedrooms nan 값 발견
# Out:
# longitude             16512
# latitude              16512
# housing_median_age    16512
# total_rooms           16512
# total_bedrooms        16354
# population            16512
# households            16512
# median_income         16512
# ocean_proximity       16512
# income_cat            16512
# dtype: int64

# %%
housing_cat = housing[['ocean_proximity']].copy()
housing_num = housing.copy()
housing_num.drop('ocean_proximity', axis=1, inplace=True)
housing_cat
# Out:
#       ocean_proximity
# 12655          INLAND
# 15502      NEAR OCEAN
# 2908           INLAND
# 14053      NEAR OCEAN
# 20496       <1H OCEAN
# ...               ...
# 15174       <1H OCEAN
# 12661          INLAND
# 19263       <1H OCEAN
# 19140       <1H OCEAN
# 19773          INLAND
#
# [16512 rows x 1 columns]

# %%
housing_num.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
#
#        population  households  median_income income_cat
# 12655      2237.0       706.0         2.1736          2
# 15502      2015.0       768.0         6.3373          5
# 2908        667.0       300.0         2.8750          2
# 14053       898.0       483.0         2.2264          2
# 20496      1837.0       580.0         4.4964          3

# %%
# rooms_per_houshold = rooms/household
# population_per_household = population/household
# bedrooms_per_room = bedrooms/rooms
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin

class MakeAttribute(BaseEstimator, TransformerMixin):
    def __init__(self, indexes):
        self.indexes=indexes
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        rooms_per_household = X[:,self.indexes.index('total_rooms')] / X[:, self.indexes.index('households')]
        population_per_household = X[:,self.indexes.index('population')] / X[:, self.indexes.index('households')]
        bedrooms_per_room = X[:,self.indexes.index('total_bedrooms')] / X[:, self.indexes.index('total_rooms')]
        
        return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('attribs_adder', MakeAttribute(list(housing_num))),
    ('standard_scaler', StandardScaler()),
])

num_attr = list(housing_num)
cat_attr = list(housing_cat)

full_pipeline = ColumnTransformer([
    ('num_pipe', num_pipeline, num_attr),
    ('cat_pipe', OneHotEncoder(), cat_attr),
])

housing_prepared = full_pipeline.fit_transform(housing)
housing_prepared
# Out:
# array([[-0.94135046,  1.34743822,  0.02756357, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.17178212, -1.19243966, -1.72201763, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.26758118, -0.1259716 ,  1.22045984, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-1.5707942 ,  1.31001828,  1.53856552, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.56080303,  1.2492109 , -1.1653327 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.28105026,  2.02567448, -0.13148926, ...,  0.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# # 1. Support Vector Machine Regression (Use GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid =[
    {'kernel':['linear'], 'C':[10., 30., 100., 300., 1000., 3000., 10000., 30000.0]},
    {'kernel':['rbf'], 'C':[1.0, 3.0, 10., 30., 100., 300., 1000.0],'gamma':[0.01, 0.03, 0.1, 0.3, 1.0, 3.0]}
]

svm_reg = SVR()
grid_search = GridSearchCV(svm_reg, param_grid, cv=5, scoring='neg_mean_squared_error', verbose=2)
grid_search.fit(housing_prepared, housing_labels)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END ..............................C=10.0, kernel=linear; total time=   7.9s
# [CV] END ..............................C=10.0, kernel=linear; total time=   7.7s
# [CV] END ..............................C=10.0, kernel=linear; total time=   7.9s
# [CV] END ..............................C=10.0, kernel=linear; total time=   8.0s
# [CV] END ..............................C=10.0, kernel=linear; total time=   7.9s
# [CV] END ..............................C=30.0, kernel=linear; total time=   7.7s
# [CV] END ..............................C=30.0, kernel=linear; total time=   7.3s
# [CV] END ..............................C=30.0, kernel=linear; total time=   7.3s
# [CV] END ..............................C=30.0, kernel=linear; total time=   7.4s
# [CV] END ..............................C=30.0, kernel=linear; total time=   7.3s
# [CV] END .............................C=100.0, kernel=linear; total time=   7.4s
# [CV] END .............................C=100.0, kernel=linear; total time=   7.4s
# [CV] END .............................C=100.0, kernel=linear; total time=   7.3s
# [CV] END .............................C=100.0, kernel=linear; total time=   7.4s
# [CV] END .............................C=100.0, kernel=linear; total time=   7.4s
# [CV] END .............................C=300.0, kernel=linear; total time=   7.5s
# [CV] END .............................C=300.0, kernel=linear; total time=   7.4s
# [CV] END .............................C=300.0, kernel=linear; total time=   7.5s
# [CV] END .............................C=300.0, kernel=linear; total time=   8.9s
# [CV] END .............................C=300.0, kernel=linear; total time=   9.3s
# [CV] END ............................C=1000.0, kernel=linear; total time=   7.6s
# [CV] END ............................C=1000.0, kernel=linear; total time=   7.7s
# [CV] END ............................C=1000.0, kernel=linear; total time=   7.7s
# [CV] END ............................C=1000.0, kernel=linear; total time=   8.3s
# [CV] END ............................C=1000.0, kernel=linear; total time=   7.5s
# [CV] END ............................C=3000.0, kernel=linear; total time=   7.9s
# [CV] END ............................C=3000.0, kernel=linear; total time=   8.3s
# [CV] END ............................C=3000.0, kernel=linear; total time=   8.9s
# [CV] END ............................C=3000.0, kernel=linear; total time=   8.3s
# [CV] END ............................C=3000.0, kernel=linear; total time=   8.7s
# [CV] END ...........................C=10000.0, kernel=linear; total time=   9.8s
# [CV] END ...........................C=10000.0, kernel=linear; total time=   9.8s
# [CV] END ...........................C=10000.0, kernel=linear; total time=   9.5s
# [CV] END ...........................C=10000.0, kernel=linear; total time=  10.2s
# [CV] END ...........................C=10000.0, kernel=linear; total time=   9.6s
# [CV] END ...........................C=30000.0, kernel=linear; total time=  13.9s
# [CV] END ...........................C=30000.0, kernel=linear; total time=  14.6s
# [CV] END ...........................C=30000.0, kernel=linear; total time=  14.1s
# [CV] END ...........................C=30000.0, kernel=linear; total time=  14.1s
# [CV] END ...........................C=30000.0, kernel=linear; total time=  14.5s
# [CV] END ......................C=1.0, gamma=0.01, kernel=rbf; total time=  14.3s
# [CV] END ......................C=1.0, gamma=0.01, kernel=rbf; total time=  14.0s
# [CV] END ......................C=1.0, gamma=0.01, kernel=rbf; total time=  14.3s
# [CV] END ......................C=1.0, gamma=0.01, kernel=rbf; total time=  14.0s
# [CV] END ......................C=1.0, gamma=0.01, kernel=rbf; total time=  14.2s
# [CV] END ......................C=1.0, gamma=0.03, kernel=rbf; total time=  13.9s
# [CV] END ......................C=1.0, gamma=0.03, kernel=rbf; total time=  13.9s
# [CV] END ......................C=1.0, gamma=0.03, kernel=rbf; total time=  14.1s
# [CV] END ......................C=1.0, gamma=0.03, kernel=rbf; total time=  14.0s
# [CV] END ......................C=1.0, gamma=0.03, kernel=rbf; total time=  15.4s
# [CV] END .......................C=1.0, gamma=0.1, kernel=rbf; total time=  14.5s
# [CV] END .......................C=1.0, gamma=0.1, kernel=rbf; total time=  13.9s
# [CV] END .......................C=1.0, gamma=0.1, kernel=rbf; total time=  15.6s
# [CV] END .......................C=1.0, gamma=0.1, kernel=rbf; total time=  15.8s
# [CV] END .......................C=1.0, gamma=0.1, kernel=rbf; total time=  14.4s
# [CV] END .......................C=1.0, gamma=0.3, kernel=rbf; total time=  13.6s
# [CV] END .......................C=1.0, gamma=0.3, kernel=rbf; total time=  13.7s
# [CV] END .......................C=1.0, gamma=0.3, kernel=rbf; total time=  13.7s
# [CV] END .......................C=1.0, gamma=0.3, kernel=rbf; total time=  13.8s
# [CV] END .......................C=1.0, gamma=0.3, kernel=rbf; total time=  13.7s
# [CV] END .......................C=1.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END .......................C=1.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END .......................C=1.0, gamma=1.0, kernel=rbf; total time=  14.0s
# [CV] END .......................C=1.0, gamma=1.0, kernel=rbf; total time=  14.0s
# [CV] END .......................C=1.0, gamma=1.0, kernel=rbf; total time=  16.1s
# [CV] END .......................C=1.0, gamma=3.0, kernel=rbf; total time=  16.3s
# [CV] END .......................C=1.0, gamma=3.0, kernel=rbf; total time=  14.8s
# [CV] END .......................C=1.0, gamma=3.0, kernel=rbf; total time=  15.9s
# [CV] END .......................C=1.0, gamma=3.0, kernel=rbf; total time=  15.7s
# [CV] END .......................C=1.0, gamma=3.0, kernel=rbf; total time=  14.7s
# [CV] END ......................C=3.0, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV] END ......................C=3.0, gamma=0.01, kernel=rbf; total time=  14.3s
# [CV] END ......................C=3.0, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV] END ......................C=3.0, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV] END ......................C=3.0, gamma=0.01, kernel=rbf; total time=  14.6s
# [CV] END ......................C=3.0, gamma=0.03, kernel=rbf; total time=  14.2s
# [CV] END ......................C=3.0, gamma=0.03, kernel=rbf; total time=  14.3s
# [CV] END ......................C=3.0, gamma=0.03, kernel=rbf; total time=  14.3s
# [CV] END ......................C=3.0, gamma=0.03, kernel=rbf; total time=  14.5s
# [CV] END ......................C=3.0, gamma=0.03, kernel=rbf; total time=  14.3s
# [CV] END .......................C=3.0, gamma=0.1, kernel=rbf; total time=  14.0s
# [CV] END .......................C=3.0, gamma=0.1, kernel=rbf; total time=  15.2s
# [CV] END .......................C=3.0, gamma=0.1, kernel=rbf; total time=  14.9s
# [CV] END .......................C=3.0, gamma=0.1, kernel=rbf; total time=  14.4s
# [CV] END .......................C=3.0, gamma=0.1, kernel=rbf; total time=  14.3s
# [CV] END .......................C=3.0, gamma=0.3, kernel=rbf; total time=  14.3s
# [CV] END .......................C=3.0, gamma=0.3, kernel=rbf; total time=  14.5s
# [CV] END .......................C=3.0, gamma=0.3, kernel=rbf; total time=  14.0s
# [CV] END .......................C=3.0, gamma=0.3, kernel=rbf; total time=  13.9s
# [CV] END .......................C=3.0, gamma=0.3, kernel=rbf; total time=  14.0s
# [CV] END .......................C=3.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END .......................C=3.0, gamma=1.0, kernel=rbf; total time=  14.5s
# [CV] END .......................C=3.0, gamma=1.0, kernel=rbf; total time=  14.7s
# [CV] END .......................C=3.0, gamma=1.0, kernel=rbf; total time=  14.1s
# [CV] END .......................C=3.0, gamma=1.0, kernel=rbf; total time=  13.9s
# [CV] END .......................C=3.0, gamma=3.0, kernel=rbf; total time=  15.8s
# [CV] END .......................C=3.0, gamma=3.0, kernel=rbf; total time=  15.3s
# [CV] END .......................C=3.0, gamma=3.0, kernel=rbf; total time=  14.7s
# [CV] END .......................C=3.0, gamma=3.0, kernel=rbf; total time=  15.5s
# [CV] END .......................C=3.0, gamma=3.0, kernel=rbf; total time=  16.1s
# [CV] END .....................C=10.0, gamma=0.01, kernel=rbf; total time=  15.2s
# [CV] END .....................C=10.0, gamma=0.01, kernel=rbf; total time=  15.1s
# [CV] END .....................C=10.0, gamma=0.01, kernel=rbf; total time=  14.5s
# [CV] END .....................C=10.0, gamma=0.01, kernel=rbf; total time=  14.3s
# [CV] END .....................C=10.0, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV] END .....................C=10.0, gamma=0.03, kernel=rbf; total time=  15.6s
# [CV] END .....................C=10.0, gamma=0.03, kernel=rbf; total time=  15.6s
# [CV] END .....................C=10.0, gamma=0.03, kernel=rbf; total time=  16.5s
# [CV] END .....................C=10.0, gamma=0.03, kernel=rbf; total time=  14.5s
# [CV] END .....................C=10.0, gamma=0.03, kernel=rbf; total time=  14.4s
# [CV] END ......................C=10.0, gamma=0.1, kernel=rbf; total time=  14.9s
# [CV] END ......................C=10.0, gamma=0.1, kernel=rbf; total time=  14.2s
# [CV] END ......................C=10.0, gamma=0.1, kernel=rbf; total time=  14.0s
# [CV] END ......................C=10.0, gamma=0.1, kernel=rbf; total time=  14.0s
# [CV] END ......................C=10.0, gamma=0.1, kernel=rbf; total time=  14.0s
# [CV] END ......................C=10.0, gamma=0.3, kernel=rbf; total time=  13.8s
# [CV] END ......................C=10.0, gamma=0.3, kernel=rbf; total time=  13.7s
# [CV] END ......................C=10.0, gamma=0.3, kernel=rbf; total time=  14.4s
# [CV] END ......................C=10.0, gamma=0.3, kernel=rbf; total time=  14.7s
# [CV] END ......................C=10.0, gamma=0.3, kernel=rbf; total time=  14.1s
# [CV] END ......................C=10.0, gamma=1.0, kernel=rbf; total time=  13.8s
# [CV] END ......................C=10.0, gamma=1.0, kernel=rbf; total time=  13.5s
# [CV] END ......................C=10.0, gamma=1.0, kernel=rbf; total time=  14.2s
# [CV] END ......................C=10.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END ......................C=10.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END ......................C=10.0, gamma=3.0, kernel=rbf; total time=  14.4s
# [CV] END ......................C=10.0, gamma=3.0, kernel=rbf; total time=  14.5s
# [CV] END ......................C=10.0, gamma=3.0, kernel=rbf; total time=  14.8s
# [CV] END ......................C=10.0, gamma=3.0, kernel=rbf; total time=  14.4s
# [CV] END ......................C=10.0, gamma=3.0, kernel=rbf; total time=  14.5s
# [CV] END .....................C=30.0, gamma=0.01, kernel=rbf; total time=  14.1s
# [CV] END .....................C=30.0, gamma=0.01, kernel=rbf; total time=  14.2s
# [CV] END .....................C=30.0, gamma=0.01, kernel=rbf; total time=  14.1s
# [CV] END .....................C=30.0, gamma=0.01, kernel=rbf; total time=  14.2s
# [CV] END .....................C=30.0, gamma=0.01, kernel=rbf; total time=  14.0s
# [CV] END .....................C=30.0, gamma=0.03, kernel=rbf; total time=  14.2s
# [CV] END .....................C=30.0, gamma=0.03, kernel=rbf; total time=  14.2s
# [CV] END .....................C=30.0, gamma=0.03, kernel=rbf; total time=  14.0s
# [CV] END .....................C=30.0, gamma=0.03, kernel=rbf; total time=  14.2s
# [CV] END .....................C=30.0, gamma=0.03, kernel=rbf; total time=  14.2s
# [CV] END ......................C=30.0, gamma=0.1, kernel=rbf; total time=  13.9s
# [CV] END ......................C=30.0, gamma=0.1, kernel=rbf; total time=  13.8s
# [CV] END ......................C=30.0, gamma=0.1, kernel=rbf; total time=  13.7s
# [CV] END ......................C=30.0, gamma=0.1, kernel=rbf; total time=  13.9s
# [CV] END ......................C=30.0, gamma=0.1, kernel=rbf; total time=  14.0s
# [CV] END ......................C=30.0, gamma=0.3, kernel=rbf; total time=  13.5s
# [CV] END ......................C=30.0, gamma=0.3, kernel=rbf; total time=  13.5s
# [CV] END ......................C=30.0, gamma=0.3, kernel=rbf; total time=  13.7s
# [CV] END ......................C=30.0, gamma=0.3, kernel=rbf; total time=  13.6s
# [CV] END ......................C=30.0, gamma=0.3, kernel=rbf; total time=  13.6s
# [CV] END ......................C=30.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END ......................C=30.0, gamma=1.0, kernel=rbf; total time=  13.3s
# [CV] END ......................C=30.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END ......................C=30.0, gamma=1.0, kernel=rbf; total time=  13.5s
# [CV] END ......................C=30.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END ......................C=30.0, gamma=3.0, kernel=rbf; total time=  14.4s
# [CV] END ......................C=30.0, gamma=3.0, kernel=rbf; total time=  14.5s
# [CV] END ......................C=30.0, gamma=3.0, kernel=rbf; total time=  14.5s
# [CV] END ......................C=30.0, gamma=3.0, kernel=rbf; total time=  14.5s
# [CV] END ......................C=30.0, gamma=3.0, kernel=rbf; total time=  14.6s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=  14.0s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=  14.0s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=  13.9s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=  14.7s
# [CV] END ....................C=100.0, gamma=0.03, kernel=rbf; total time=  15.1s
# [CV] END ....................C=100.0, gamma=0.03, kernel=rbf; total time=  13.6s
# [CV] END ....................C=100.0, gamma=0.03, kernel=rbf; total time=  13.5s
# [CV] END ....................C=100.0, gamma=0.03, kernel=rbf; total time=  13.5s
# [CV] END ....................C=100.0, gamma=0.03, kernel=rbf; total time=  13.9s
# [CV] END .....................C=100.0, gamma=0.1, kernel=rbf; total time=  13.5s
# [CV] END .....................C=100.0, gamma=0.1, kernel=rbf; total time=  13.5s
# [CV] END .....................C=100.0, gamma=0.1, kernel=rbf; total time=  13.4s
# [CV] END .....................C=100.0, gamma=0.1, kernel=rbf; total time=  13.4s
# [CV] END .....................C=100.0, gamma=0.1, kernel=rbf; total time=  13.3s
# [CV] END .....................C=100.0, gamma=0.3, kernel=rbf; total time=  13.2s
# [CV] END .....................C=100.0, gamma=0.3, kernel=rbf; total time=  13.3s
# [CV] END .....................C=100.0, gamma=0.3, kernel=rbf; total time=  13.3s
# [CV] END .....................C=100.0, gamma=0.3, kernel=rbf; total time=  13.4s
# [CV] END .....................C=100.0, gamma=0.3, kernel=rbf; total time=  13.2s
# [CV] END .....................C=100.0, gamma=1.0, kernel=rbf; total time=  13.1s
# [CV] END .....................C=100.0, gamma=1.0, kernel=rbf; total time=  13.1s
# [CV] END .....................C=100.0, gamma=1.0, kernel=rbf; total time=  13.1s
# [CV] END .....................C=100.0, gamma=1.0, kernel=rbf; total time=  13.2s
# [CV] END .....................C=100.0, gamma=1.0, kernel=rbf; total time=  13.2s
# [CV] END .....................C=100.0, gamma=3.0, kernel=rbf; total time=  14.3s
# [CV] END .....................C=100.0, gamma=3.0, kernel=rbf; total time=  14.2s
# [CV] END .....................C=100.0, gamma=3.0, kernel=rbf; total time=  14.6s
# [CV] END .....................C=100.0, gamma=3.0, kernel=rbf; total time=  14.2s
# [CV] END .....................C=100.0, gamma=3.0, kernel=rbf; total time=  14.2s
# [CV] END ....................C=300.0, gamma=0.01, kernel=rbf; total time=  13.6s
# [CV] END ....................C=300.0, gamma=0.01, kernel=rbf; total time=  13.8s
# [CV] END ....................C=300.0, gamma=0.01, kernel=rbf; total time=  13.6s
# [CV] END ....................C=300.0, gamma=0.01, kernel=rbf; total time=  13.6s
# [CV] END ....................C=300.0, gamma=0.01, kernel=rbf; total time=  14.1s
# [CV] END ....................C=300.0, gamma=0.03, kernel=rbf; total time=  13.4s
# [CV] END ....................C=300.0, gamma=0.03, kernel=rbf; total time=  13.5s
# [CV] END ....................C=300.0, gamma=0.03, kernel=rbf; total time=  13.3s
# [CV] END ....................C=300.0, gamma=0.03, kernel=rbf; total time=  13.2s
# [CV] END ....................C=300.0, gamma=0.03, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=0.1, kernel=rbf; total time=  13.2s
# [CV] END .....................C=300.0, gamma=0.1, kernel=rbf; total time=  13.2s
# [CV] END .....................C=300.0, gamma=0.1, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=0.1, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=0.1, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=0.3, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=0.3, kernel=rbf; total time=  13.2s
# [CV] END .....................C=300.0, gamma=0.3, kernel=rbf; total time=  13.4s
# [CV] END .....................C=300.0, gamma=0.3, kernel=rbf; total time=  13.2s
# [CV] END .....................C=300.0, gamma=0.3, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=1.0, kernel=rbf; total time=  13.1s
# [CV] END .....................C=300.0, gamma=1.0, kernel=rbf; total time=  13.2s
# [CV] END .....................C=300.0, gamma=1.0, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=1.0, kernel=rbf; total time=  13.3s
# [CV] END .....................C=300.0, gamma=1.0, kernel=rbf; total time=  13.4s
# [CV] END .....................C=300.0, gamma=3.0, kernel=rbf; total time=  14.3s
# [CV] END .....................C=300.0, gamma=3.0, kernel=rbf; total time=  14.4s
# [CV] END .....................C=300.0, gamma=3.0, kernel=rbf; total time=  14.4s
# [CV] END .....................C=300.0, gamma=3.0, kernel=rbf; total time=  14.4s
# [CV] END .....................C=300.0, gamma=3.0, kernel=rbf; total time=  14.3s
# [CV] END ...................C=1000.0, gamma=0.01, kernel=rbf; total time=  13.3s
# [CV] END ...................C=1000.0, gamma=0.01, kernel=rbf; total time=  13.5s
# [CV] END ...................C=1000.0, gamma=0.01, kernel=rbf; total time=  13.4s
# [CV] END ...................C=1000.0, gamma=0.01, kernel=rbf; total time=  14.6s
# [CV] END ...................C=1000.0, gamma=0.01, kernel=rbf; total time=  14.2s
# [CV] END ...................C=1000.0, gamma=0.03, kernel=rbf; total time=  13.3s
# [CV] END ...................C=1000.0, gamma=0.03, kernel=rbf; total time=  13.6s
# [CV] END ...................C=1000.0, gamma=0.03, kernel=rbf; total time=  14.9s
# [CV] END ...................C=1000.0, gamma=0.03, kernel=rbf; total time=  14.3s
# [CV] END ...................C=1000.0, gamma=0.03, kernel=rbf; total time=  13.8s
# [CV] END ....................C=1000.0, gamma=0.1, kernel=rbf; total time=  15.2s
# [CV] END ....................C=1000.0, gamma=0.1, kernel=rbf; total time=  13.6s
# [CV] END ....................C=1000.0, gamma=0.1, kernel=rbf; total time=  14.3s
# [CV] END ....................C=1000.0, gamma=0.1, kernel=rbf; total time=  14.5s
# [CV] END ....................C=1000.0, gamma=0.1, kernel=rbf; total time=  13.7s
# [CV] END ....................C=1000.0, gamma=0.3, kernel=rbf; total time=  13.7s
# [CV] END ....................C=1000.0, gamma=0.3, kernel=rbf; total time=  13.9s
# [CV] END ....................C=1000.0, gamma=0.3, kernel=rbf; total time=  15.8s
# [CV] END ....................C=1000.0, gamma=0.3, kernel=rbf; total time=  13.8s
# [CV] END ....................C=1000.0, gamma=0.3, kernel=rbf; total time=  15.0s
# [CV] END ....................C=1000.0, gamma=1.0, kernel=rbf; total time=  13.8s
# [CV] END ....................C=1000.0, gamma=1.0, kernel=rbf; total time=  13.3s
# [CV] END ....................C=1000.0, gamma=1.0, kernel=rbf; total time=  14.2s
# [CV] END ....................C=1000.0, gamma=1.0, kernel=rbf; total time=  13.5s
# [CV] END ....................C=1000.0, gamma=1.0, kernel=rbf; total time=  13.5s
# [CV] END ....................C=1000.0, gamma=3.0, kernel=rbf; total time=  14.6s
# [CV] END ....................C=1000.0, gamma=3.0, kernel=rbf; total time=  14.6s
# [CV] END ....................C=1000.0, gamma=3.0, kernel=rbf; total time=  14.7s
# [CV] END ....................C=1000.0, gamma=3.0, kernel=rbf; total time=  14.8s
# [CV] END ....................C=1000.0, gamma=3.0, kernel=rbf; total time=  14.6s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid=[{'C': [10.0, 30.0, 100.0, 300.0, 1000.0, 3000.0,
#                                 10000.0, 30000.0],
#                           'kernel': ['linear']},
#                          {'C': [1.0, 3.0, 10.0, 30.0, 100.0, 300.0, 1000.0],
#                           'gamma': [0.01, 0.03, 0.1, 0.3, 1.0, 3.0],
#                           'kernel': ['rbf']}],
#              scoring='neg_mean_squared_error', verbose=2)

# %%
negative_mse = grid_search.best_score_
rmse = np.sqrt(-negative_mse)
rmse
# Out:
# 70279.30954066859

# %%
grid_search.best_params_
# Out:
# {'C': 1000.0, 'kernel': 'linear'}

# %% [markdown]
# # 2. GridsearchCV to RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, expon

param_distribs = {
    'kernel':['linear', 'rbf'], 'C':randint(low=20, high=200000), 'gamma': expon(scale=1.0),
}

svm_reg2 = SVR()
rnd_search = RandomizedSearchCV(svm_reg2, param_distributions=param_distribs, n_iter=50, cv=5, scoring='neg_mean_squared_error', verbose=2, random_state=42)
rnd_search.fit(housing_prepared, housing_labels)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END ..C=121978, gamma=1.5923005340557224, kernel=linear; total time=  34.0s
# [CV] END ..C=121978, gamma=1.5923005340557224, kernel=linear; total time=  39.0s
# [CV] END ..C=121978, gamma=1.5923005340557224, kernel=linear; total time=  31.7s
# [CV] END ..C=121978, gamma=1.5923005340557224, kernel=linear; total time=  34.3s
# [CV] END ..C=121978, gamma=1.5923005340557224, kernel=linear; total time=  32.8s
# [CV] END ..C=119899, gamma=0.9129425537759532, kernel=linear; total time=  32.1s
# [CV] END ..C=119899, gamma=0.9129425537759532, kernel=linear; total time=  36.7s
# [CV] END ..C=119899, gamma=0.9129425537759532, kernel=linear; total time=  31.8s
# [CV] END ..C=119899, gamma=0.9129425537759532, kernel=linear; total time=  35.2s
# [CV] END ..C=119899, gamma=0.9129425537759532, kernel=linear; total time=  33.4s
# [CV] END .C=137357, gamma=0.16959629191460518, kernel=linear; total time=  39.4s
# [CV] END .C=137357, gamma=0.16959629191460518, kernel=linear; total time=  46.2s
# [CV] END .C=137357, gamma=0.16959629191460518, kernel=linear; total time=  32.8s
# [CV] END .C=137357, gamma=0.16959629191460518, kernel=linear; total time=  38.8s
# [CV] END .C=137357, gamma=0.16959629191460518, kernel=linear; total time=  32.1s
# [CV] END ......C=87518, gamma=2.0112308644799395, kernel=rbf; total time= 1.2min
# [CV] END ......C=87518, gamma=2.0112308644799395, kernel=rbf; total time= 1.5min
# [CV] END ......C=87518, gamma=2.0112308644799395, kernel=rbf; total time= 1.3min
# [CV] END ......C=87518, gamma=2.0112308644799395, kernel=rbf; total time= 1.3min
# [CV] END ......C=87518, gamma=2.0112308644799395, kernel=rbf; total time= 1.3min
# [CV] END .....C=191355, gamma=1.2312500617045903, kernel=rbf; total time= 3.1min
# [CV] END .....C=191355, gamma=1.2312500617045903, kernel=rbf; total time= 2.3min
# [CV] END .....C=191355, gamma=1.2312500617045903, kernel=rbf; total time= 2.1min
# [CV] END .....C=191355, gamma=1.2312500617045903, kernel=rbf; total time= 2.9min
# [CV] END .....C=191355, gamma=1.2312500617045903, kernel=rbf; total time= 2.5min
# [CV] END .......C=64840, gamma=3.503557475158312, kernel=rbf; total time=  59.1s
# [CV] END .......C=64840, gamma=3.503557475158312, kernel=rbf; total time= 1.1min
# [CV] END .......C=64840, gamma=3.503557475158312, kernel=rbf; total time= 1.0min
# [CV] END .......C=64840, gamma=3.503557475158312, kernel=rbf; total time= 1.1min
# [CV] END .......C=64840, gamma=3.503557475158312, kernel=rbf; total time= 1.0min
# [CV] END .......C=64945, gamma=0.238687625248947, kernel=rbf; total time=  17.6s
# [CV] END .......C=64945, gamma=0.238687625248947, kernel=rbf; total time=  18.0s
# [CV] END .......C=64945, gamma=0.238687625248947, kernel=rbf; total time=  17.3s
# [CV] END .......C=64945, gamma=0.238687625248947, kernel=rbf; total time=  16.6s
# [CV] END .......C=64945, gamma=0.238687625248947, kernel=rbf; total time=  16.7s
# [CV] END ....C=103375, gamma=0.20261142283225705, kernel=rbf; total time=  19.3s
# [CV] END ....C=103375, gamma=0.20261142283225705, kernel=rbf; total time=  21.0s
# [CV] END ....C=103375, gamma=0.20261142283225705, kernel=rbf; total time=  18.7s
# [CV] END ....C=103375, gamma=0.20261142283225705, kernel=rbf; total time=  19.0s
# [CV] END ....C=103375, gamma=0.20261142283225705, kernel=rbf; total time=  20.1s
# [CV] END ......C=85325, gamma=0.7439278308608545, kernel=rbf; total time=  28.8s
# [CV] END ......C=85325, gamma=0.7439278308608545, kernel=rbf; total time=  27.6s
# [CV] END ......C=85325, gamma=0.7439278308608545, kernel=rbf; total time=  31.4s
# [CV] END ......C=85325, gamma=0.7439278308608545, kernel=rbf; total time=  30.1s
# [CV] END ......C=85325, gamma=0.7439278308608545, kernel=rbf; total time=  28.2s
# [CV] END ..C=130628, gamma=0.7439661879833189, kernel=linear; total time=  32.4s
# [CV] END ..C=130628, gamma=0.7439661879833189, kernel=linear; total time=  32.3s
# [CV] END ..C=130628, gamma=0.7439661879833189, kernel=linear; total time=  33.9s
# [CV] END ..C=130628, gamma=0.7439661879833189, kernel=linear; total time=  34.9s
# [CV] END ..C=130628, gamma=0.7439661879833189, kernel=linear; total time=  36.1s
# [CV] END ....C=122557, gamma=0.04778961126377175, kernel=rbf; total time=  14.4s
# [CV] END ....C=122557, gamma=0.04778961126377175, kernel=rbf; total time=  14.3s
# [CV] END ....C=122557, gamma=0.04778961126377175, kernel=rbf; total time=  14.4s
# [CV] END ....C=122557, gamma=0.04778961126377175, kernel=rbf; total time=  14.5s
# [CV] END ....C=122557, gamma=0.04778961126377175, kernel=rbf; total time=  14.2s
# [CV] END ..C=40417, gamma=0.21813469463126745, kernel=linear; total time=  16.2s
# [CV] END ..C=40417, gamma=0.21813469463126745, kernel=linear; total time=  18.8s
# [CV] END ...C=55611, gamma=1.8613272474446172, kernel=linear; total time=  20.6s
# [CV] END ...C=55611, gamma=1.8613272474446172, kernel=linear; total time=  20.6s
# [CV] END ...C=55611, gamma=1.8613272474446172, kernel=linear; total time=  18.7s
# [CV] END ...C=55611, gamma=1.8613272474446172, kernel=linear; total time=  19.4s
# [CV] END ...C=55611, gamma=1.8613272474446172, kernel=linear; total time=  22.4s
# [CV] END .......C=82818, gamma=1.764557865240934, kernel=rbf; total time= 1.1min
# [CV] END .......C=82818, gamma=1.764557865240934, kernel=rbf; total time= 1.1min
# [CV] END .......C=82818, gamma=1.764557865240934, kernel=rbf; total time= 1.2min
# [CV] END .......C=82818, gamma=1.764557865240934, kernel=rbf; total time= 1.2min
# [CV] END .......C=82818, gamma=1.764557865240934, kernel=rbf; total time= 1.1min
# [CV] END .....C=194796, gamma=0.3298028401342492, kernel=rbf; total time=  42.9s
# [CV] END .....C=194796, gamma=0.3298028401342492, kernel=rbf; total time=  38.3s
# [CV] END .....C=194796, gamma=0.3298028401342492, kernel=rbf; total time=  46.0s
# [CV] END .....C=194796, gamma=0.3298028401342492, kernel=rbf; total time=  41.5s
# [CV] END .....C=194796, gamma=0.3298028401342492, kernel=rbf; total time=  45.8s
# [CV] END ...C=38064, gamma=1.6204835957747312, kernel=linear; total time=  16.5s
# [CV] END ...C=38064, gamma=1.6204835957747312, kernel=linear; total time=  16.9s
# [CV] END ...C=38064, gamma=1.6204835957747312, kernel=linear; total time=  16.1s
# [CV] END ...C=38064, gamma=1.6204835957747312, kernel=linear; total time=  16.3s
# [CV] END ...C=38064, gamma=1.6204835957747312, kernel=linear; total time=  14.9s
# [CV] END ........C=49004, gamma=4.33414633958732, kernel=rbf; total time=  44.2s
# [CV] END ........C=49004, gamma=4.33414633958732, kernel=rbf; total time=  44.1s
# [CV] END ........C=49004, gamma=4.33414633958732, kernel=rbf; total time=  44.6s
# [CV] END ........C=49004, gamma=4.33414633958732, kernel=rbf; total time=  44.7s
# [CV] END ........C=49004, gamma=4.33414633958732, kernel=rbf; total time=  44.5s
# [CV] END ....C=193684, gamma=0.22153944050588595, kernel=rbf; total time=  31.9s
# [CV] END ....C=193684, gamma=0.22153944050588595, kernel=rbf; total time=  31.5s
# [CV] END ....C=193684, gamma=0.22153944050588595, kernel=rbf; total time=  33.5s
# [CV] END ....C=193684, gamma=0.22153944050588595, kernel=rbf; total time=  32.7s
# [CV] END ....C=193684, gamma=0.22153944050588595, kernel=rbf; total time=  33.8s
# [CV] END ...C=179282, gamma=1.689896777486126, kernel=linear; total time=  44.5s
# [CV] END ...C=179282, gamma=1.689896777486126, kernel=linear; total time=  37.2s
# [CV] END ...C=179282, gamma=1.689896777486126, kernel=linear; total time=  50.9s
# [CV] END ...C=179282, gamma=1.689896777486126, kernel=linear; total time=  46.2s
# [CV] END ...C=113272, gamma=3.565320964602151, kernel=linear; total time=  32.0s
# [CV] END ...C=113272, gamma=3.565320964602151, kernel=linear; total time=  28.9s
# [CV] END ...C=113272, gamma=3.565320964602151, kernel=linear; total time=  32.5s
# [CV] END ...C=113272, gamma=3.565320964602151, kernel=linear; total time=  31.3s
# [CV] END ..C=184084, gamma=1.2791616928460479, kernel=linear; total time=  39.4s
# [CV] END ..C=184084, gamma=1.2791616928460479, kernel=linear; total time=  38.5s
# [CV] END ..C=184084, gamma=1.2791616928460479, kernel=linear; total time=  43.2s
# [CV] END ..C=184084, gamma=1.2791616928460479, kernel=linear; total time=  45.2s
# [CV] END ..C=184084, gamma=1.2791616928460479, kernel=linear; total time=  47.4s
# [CV] END ..C=138002, gamma=0.2958060800342772, kernel=linear; total time=  39.8s
# [CV] END ..C=138002, gamma=0.2958060800342772, kernel=linear; total time=  39.5s
# [CV] END ..C=138002, gamma=0.2958060800342772, kernel=linear; total time=  32.5s
# [CV] END ..C=138002, gamma=0.2958060800342772, kernel=linear; total time=  35.8s
# [CV] END ..C=138002, gamma=0.2958060800342772, kernel=linear; total time=  33.9s
# [CV] END .....C=119196, gamma=1.2401627989937203, kernel=rbf; total time= 1.4min
# [CV] END .....C=119196, gamma=1.2401627989937203, kernel=rbf; total time= 1.5min
# [CV] END .....C=119196, gamma=1.2401627989937203, kernel=rbf; total time= 1.3min
# [CV] END .....C=119196, gamma=1.2401627989937203, kernel=rbf; total time= 1.5min
# [CV] END .....C=119196, gamma=1.2401627989937203, kernel=rbf; total time= 1.4min
# [CV] END ...C=122429, gamma=0.578634378499143, kernel=linear; total time=  34.6s
# [CV] END ...C=122429, gamma=0.578634378499143, kernel=linear; total time=  31.6s
# [CV] END ...C=122429, gamma=0.578634378499143, kernel=linear; total time=  30.4s
# [CV] END ...C=122429, gamma=0.578634378499143, kernel=linear; total time=  30.5s
# [CV] END ...C=122429, gamma=0.578634378499143, kernel=linear; total time=  31.6s
# [CV] END ......C=50035, gamma=1.0117295509275495, kernel=rbf; total time=  21.7s
# [CV] END ......C=50035, gamma=1.0117295509275495, kernel=rbf; total time=  21.0s
# [CV] END ......C=50035, gamma=1.0117295509275495, kernel=rbf; total time=  22.4s
# [CV] END ......C=50035, gamma=1.0117295509275495, kernel=rbf; total time=  22.2s
# [CV] END ......C=50035, gamma=1.0117295509275495, kernel=rbf; total time=  23.2s
# [CV] END .....C=185360, gamma=0.7104371771341901, kernel=rbf; total time= 1.6min
# [CV] END .....C=185360, gamma=0.7104371771341901, kernel=rbf; total time= 1.6min
# [CV] END .....C=185360, gamma=0.7104371771341901, kernel=rbf; total time= 1.4min
# [CV] END .....C=185360, gamma=0.7104371771341901, kernel=rbf; total time= 1.6min
# [CV] END .....C=185360, gamma=0.7104371771341901, kernel=rbf; total time= 1.4min
# [CV] END ..C=105898, gamma=0.9273956116389813, kernel=linear; total time=  31.5s
# [CV] END ..C=105898, gamma=0.9273956116389813, kernel=linear; total time=  29.3s
# [CV] END ..C=105898, gamma=0.9273956116389813, kernel=linear; total time=  29.1s
# [CV] END ..C=105898, gamma=0.9273956116389813, kernel=linear; total time=  32.8s
# [CV] END ..C=105898, gamma=0.9273956116389813, kernel=linear; total time=  30.7s
# [CV] END ..C=164919, gamma=2.8621383676481322, kernel=linear; total time=  47.8s
# [CV] END ..C=164919, gamma=2.8621383676481322, kernel=linear; total time=  41.2s
# [CV] END ..C=164919, gamma=2.8621383676481322, kernel=linear; total time=  37.9s
# [CV] END ..C=164919, gamma=2.8621383676481322, kernel=linear; total time=  40.3s
# [CV] END ..C=164919, gamma=2.8621383676481322, kernel=linear; total time=  42.5s
# [CV] END ......C=75470, gamma=1.1867386132926785, kernel=rbf; total time=  49.1s
# [CV] END ......C=75470, gamma=1.1867386132926785, kernel=rbf; total time=  46.7s
# [CV] END ......C=75470, gamma=1.1867386132926785, kernel=rbf; total time=  44.0s
# [CV] END ......C=75470, gamma=1.1867386132926785, kernel=rbf; total time=  44.8s
# [CV] END ......C=75470, gamma=1.1867386132926785, kernel=rbf; total time=  51.0s
# RandomizedSearchCV(cv=5, estimator=SVR(), n_iter=50,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002581DA9A390>,
#                                         'gamma': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002581DA9AC88>,
#                                         'kernel': ['linear', 'rbf']},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
negative_mse2 = rnd_search.best_score_
rmse2 = np.sqrt(-negative_mse2) 
rmse2
# Out:
# 55065.35247199966

# %%
rnd_search.best_params_
# Out:
# {'C': 193684, 'gamma': 0.22153944050588595, 'kernel': 'rbf'}

# %% [markdown]
# # 3. Make Convertor to Select Best Attribute (Use Pipeline)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class SelectBestAttribute(BaseEstimator, TransformerMixin):
    def __init__(self, feature_importances, k):
        self.feature_importances = feature_importances
        self.k = k
    def indices_of_top_k(self):
        return np.sort(np.argpartition(np.array(self.feature_importances), -self.k)[-self.k:]) # 관련이 큰 k개의 변수를 배열의 오른쪽에 순서에 상관없이 몰아 놓고 [-k:] 로 k 이상만 슬라이스
    def fit(self, X, y=None):
        self.feature_indices_ = self.indices_of_top_k()
        return self
    def transform(self, X):
        return X[:, self.feature_indices_]

# %%
# feature_importances_ 산출을 위한 RandomForest Regression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import randint

param_distribs = {
    'n_estimators':randint(low=1, high=200),
    'max_features':randint(low=1, high=8),
}

forest_reg = RandomForestRegressor(random_state=42)
rnd_search2 = RandomizedSearchCV(forest_reg, param_distributions=param_distribs, n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42)
rnd_search2.fit(housing_prepared, housing_labels)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    param_distributions={'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002582EE2A710>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002582EE0FCC0>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
feature_importances = rnd_search2.best_estimator_.feature_importances_
feature_importances
# Out:
# array([6.56863167e-02, 5.97871721e-02, 4.46517157e-02, 1.68844069e-02,
#        1.65147541e-02, 1.65530829e-02, 1.61759635e-02, 2.76212740e-01,
#        1.41219128e-01, 3.87967033e-02, 1.07825748e-01, 4.94744854e-02,
#        9.11577527e-03, 1.33517348e-01, 7.63049962e-05, 3.49438421e-03,
#        4.01397065e-03])

# %%
k=5

top_k_features_indices = np.sort(np.argpartition(np.array(feature_importances), -k)[-k:])
top_k_features_indices
# Out:
# array([ 0,  7,  8, 10, 13], dtype=int64)

# %%
preparation_and_feature_selection_pipeline = Pipeline([
    ('preperation', full_pipeline),
    ('feature_selection', SelectBestAttribute(feature_importances, k))
])
housing_prepared_top_k_features = preparation_and_feature_selection_pipeline.fit_transform(housing)
housing_prepared_top_k_features
# Out:
# array([[-0.94135046, -0.8936472 , -0.95468705,  0.00622264,  1.        ],
#        [ 1.17178212,  1.292168  ,  1.89007821, -0.04081077,  0.        ],
#        [ 0.26758118, -0.52543365, -0.95468705, -0.07537122,  1.        ],
#        ...,
#        [-1.5707942 , -0.36547546, -0.00643196, -0.03743619,  0.        ],
#        [-1.56080303,  0.16826095, -0.00643196, -0.05915604,  0.        ],
#        [-1.28105026, -0.390569  , -0.00643196,  0.00657083,  1.        ]])

# %% [markdown]
# # 4. Datasets make (Use One Pipeline)

# %%
prepare_select_and_predict_pipeline = Pipeline([
    ('preparation', full_pipeline),
    ('feature_selection', SelectBestAttribute(feature_importances, k)),
    ('svm_reg', SVR(**rnd_search.best_params_))
])

# %%
prepare_select_and_predict_pipeline.fit(housing, housing_labels)
# Out:
# Pipeline(steps=[('preparation',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('attribs_adder',
#                                                                    MakeAttribute(indexes=['longitude',
#                                                                                           'latitude',
#                                                                                           'housing_median_age',
#                                                                                           'total_rooms',
#                                                                                           'total_bedrooms',
#                                                                                           'population',
#                                                                                           'households',
#                                                                                           'median_income',
#                                                                                           'income_cat'])),
#                                                                   ('standard_scaler',
#                                                                    StandardScaler())]),
#                                                   ['...
#                  SelectBestAttribute(feature_importances=array([6.56863167e-02, 5.97871721e-02, 4.46517157e-02, 1.68844069e-02,
#        1.65147541e-02, 1.65530829e-02, 1.61759635e-02, 2.76212740e-01,
#        1.41219128e-01, 3.87967033e-02, 1.07825748e-01, 4.94744854e-02,
#        9.11577527e-03, 1.33517348e-01, 7.63049962e-05, 3.49438421e-03,
#        4.01397065e-03]),
#                                      k=5)),
#                 ('svm_reg', SVR(C=193684, gamma=0.22153944050588595))])

# %%
some_data = housing.iloc[:4]
some_labels = housing_labels.iloc[:4]

print("Predictions:\t", prepare_select_and_predict_pipeline.predict(some_data))
print("Labels:\t\t", list(some_labels))
# Out:
# Predictions:	 [ 82978.26321069 297653.39290231 100891.99928164 152210.9357997 ]
# Labels:		 [72100.0, 279600.0, 82700.0, 112500.0]

# %% [markdown]
# # 5. Search Options for Ready (Use GridSearchCV)

# %%
full_pipeline.named_transformers_["cat"].handle_unknown = 'ignore'

param_grid = [{
    'preparation__num__imputer__strategy': ['mean', 'median', 'most_frequent'],
    'feature_selection__k': list(range(1, len(feature_importances) + 1))
}]

grid_search_prep = GridSearchCV(prepare_select_and_predict_pipeline, param_grid, cv=5,
                                scoring='neg_mean_squared_error', verbose=2)
grid_search_prep.fit(housing, housing_labels)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16168/176894826.py in <module>
# ----> 1 full_pipeline.named_transformers_["cat"].handle_unknown = 'ignore'
#       2
#       3 param_grid = [{
#       4     'preparation__num__imputer__strategy': ['mean', 'median', 'most_frequent'],
#       5     'feature_selection__k': list(range(1, len(feature_importances) + 1))
#
# KeyError: 'cat'
